# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
from matplotlib import pyplot as plt

# %%
np.random.seed(42)
data = np.random.randn(100).cumsum()
ts = pd.Series(data, index=pd.date_range(start='2020-01-01', periods=len(data), freq='D'))
print(ts.head())
# Out:
# 2020-01-01    0.496714
# 2020-01-02    0.358450
# 2020-01-03    1.006138
# 2020-01-04    2.529168
# 2020-01-05    2.295015
# Freq: D, dtype: float64

# %%
td = pd.DataFrame(ts)
td
# Out:
#                     0
# 2020-01-01   0.496714
# 2020-01-02   0.358450
# 2020-01-03   1.006138
# 2020-01-04   2.529168
# 2020-01-05   2.295015
# ...               ...
# 2020-04-05 -10.712354
# 2020-04-06 -10.416233
# 2020-04-07 -10.155178
# 2020-04-08 -10.150065
# 2020-04-09 -10.384652
#
# [100 rows x 1 columns]

# %%
plt.plot(td.index, td[0])

# %%
result = adfuller(td)

print('Statystyka testowa: %f' % result[0])
print('p-wartosc: %f' %result[1])
print('Liczba opoznien uzyta: %d' %result[2])
print('Liczba obserwacji: %d' %result[3])
print('wartosc krytyczne:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))

if result[0] < result[4]['5%']:
    print('Szereg czasowy jest stacjonarny')
else:
    print('Szereg czasowy nie jest stacjonarny')
# Out:
# Statystyka testowa: -1.358332
# p-wartosc: 0.602081
# Liczba opoznien uzyta: 0
# Liczba obserwacji: 99
# wartosc krytyczne:
# 	1%: -3.498
# 	5%: -2.891
# 	10%: -2.583
# Szereg czasowy nie jest stacjonarny
