# %%
import re

# %%
result = re.match(r"\d{3}-\d{3}-\d{3}", "My phone number kurwa is 132-243-456")
print(result)
# Out:
# None

# %%
pattern = r"(\d{3})-(\d{3})-(\d{3})"
text = "132-243-456 is my phone number kurwa"
result = re.match(pattern, text)
print(result)
# Out:
# <re.Match object; span=(0, 11), match='132-243-456'>

# %%
print(type(result))
# Out:
# <class 're.Match'>

# %%
result
# Out:
# <re.Match object; span=(0, 11), match='132-243-456'>

# %%
result.start()
# Out:
# 0

# %%
result.end()
# Out:
# 11

# %%
text[result.start():result.end()]
# Out:
# '132-243-456'

# %% [raw]
# print(result.match())

# %%
"span" in dir(result)
# Out:
# True

# %%
result.span()
# Out:
# (0, 11)

# %%
result.group()
# Out:
# '132-243-456'

# %%
print(result.group())
# Out:
# 132-243-456

# %%
print(result.groups())
# Out:
# ('132', '243', '456')

# %%
print(result.groups(0))
# Out:
# ('132', '243', '456')

# %%
result.start(0)
# Out:
# 0

# %%
result.start(1)
# Out:
# 0

# %%
result.start(2)
# Out:
# 4

# %%
result.start(0)
# Out:
# 0

# %%
result.end(3)
# Out:
# 11

# %%
result.span(3)
# Out:
# (8, 11)

# %%
result.groups()
# Out:
# ('132', '243', '456')

# %%
text_2 = "Contact me at 123-452-8562 or 758-563-5212"
pattern_2 = r"(\d{3})-(\d{3})-(\d{3})"
result_2 = re.search(pattern_2, text_2)
print(result_2)
print(f"Found: {result_2.group(), result_2.groups()}")
# Out:
# <re.Match object; span=(14, 25), match='123-452-856'>
# Found: ('123-452-856', ('123', '452', '856'))

# %%
text_3 = "Send email to example@test.com and info@company.org or jebal@cie.pies"
pattern_3 = r"\b[A-Za-z0-9_\-.]+@([A-Za-z0-9_\-.]+)\.([A-Za-z0-9]{2,}\b)"
result_3 = re.findall(pattern_3, text_3)
print(result_3)
# Out:
# [('test', 'com'), ('company', 'org'), ('cie', 'pies')]

# %%
type(result_3)
# Out:
# list

# %%
log_data = "2023-01-01 entry, 2024-02-02 entry, 2025-03-03 entry"
pattern_data_log = r"\d{4}-\d{2}-\d{2}"

result_data_log = re.findall(pattern_data_log, log_data)
result_data_log
# Out:
# ['2023-01-01', '2024-02-02', '2025-03-03']

# %%
matches = re.finditer(pattern_data_log, log_data)
print(list(matches))
# Out:
# [<re.Match object; span=(0, 10), match='2023-01-01'>, <re.Match object; span=(18, 28), match='2024-02-02'>, <re.Match object; span=(36, 46), match='2025-03-03'>]

# %%
matches = re.finditer(pattern_data_log, log_data)
for match in matches:
    print(match)
# Out:
# <re.Match object; span=(0, 10), match='2023-01-01'>
# <re.Match object; span=(18, 28), match='2024-02-02'>
# <re.Match object; span=(36, 46), match='2025-03-03'>

# %%
text_4 = "chuj, cwel, szmata, kurwa"
pattern_4 = ", "

downy = re.split(pattern_4, text_4)
downy
# Out:
# ['chuj', 'cwel', 'szmata', 'kurwa']

# %%
text_2 = "Contact me at 123-452-8562 or 758-563-5212"
pattern_5 = "\d"

result_5 = re.sub(pattern_5, "#", text_2)
print(result_5)
# Out:
# Contact me at ###-###-#### or ###-###-####

# %%
pattern_phone = re.compile(pattern_2)

print(type(pattern_phone))
print(dir(pattern_phone))
# Out:
# <class 're.Pattern'>
# ['__class__', '__copy__', '__deepcopy__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'findall', 'finditer', 'flags', 'fullmatch', 'groupindex', 'groups', 'match', 'pattern', 'scanner', 'search', 'split', 'sub', 'subn']

# %%
result_6 = pattern_phone.search(text_2)
print(result_6.group())
# Out:
# 123-452-856

# %%
result_7 = pattern_phone.findall(text_2)
print(result_7)
# Out:
# [('123', '452', '856'), ('758', '563', '521')]

# %%
text_Alice = "Alice ty kurwo szmato 456e57 pierdolona bydlo skurwiale 454557 Alicy ty wywloko Babo boktryzr 555 gjdrt"

# %%
result_Alice_1 = re.match(r'Alice', text_Alice)
print(result_Alice_1)
# Out:
# <re.Match object; span=(0, 5), match='Alice'>

# %%
result_Alice_2 = re.search(r'\d{1,}', text_Alice)
print(result_Alice_2)
# Out:
# <re.Match object; span=(22, 25), match='456'>

# %%
result_Alice_3 = re.findall(r'[bB][a-z]{1,}', text_Alice)
print(result_Alice_3)
# Out:
# ['bydlo', 'Babo', 'boktryzr']

# %% [markdown]
# ### Praca z plikiem HTML

# %%
with open ("strona.html", encoding="utf-8") as f:
    content = f.read()

print(content)
# Out:
# <!-- saved from url=(0036)https://mobalytics.gg/tft/team-comps -->
# <html><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta name="color-scheme" content="light dark"></head><body><div class="line-gutter-backdrop"></div><form autocomplete="off"><label class="line-wrap-control">Zawijanie wierszy<input type="checkbox" aria-label="Zawijanie wierszy"></label></form><table><tbody><tr><td class="line-number" value="1"></td><td class="line-content"><span class="html-doctype">&lt;!doctype html&gt;</span><span class="html-tag">&lt;html <span class="html-attribute-name">lang</span>="<span class="html-attribute-value">en</span>"&gt;</span><span class="html-tag">&lt;head&gt;</span><span class="html-tag">&lt;meta <span class="html-attribute-name">charset</span>="<span class="html-attribute-value">utf-8</span>"/&gt;</span><span class="html-tag">&lt;meta <span class="html-attribute-name">name</span>="<span class="html-attribute-value">viewport</span>" <span class="html-attribute-name">content</span>="<span class="html-attribute-value">width=device-width,initial-scale=1,shrink-to-fit=no</span>"/&gt;</span><span class="html-tag">&lt;title <span class="html-attribute-name">data-rh</span>="<span class="html-attribute-value">true</span>"&gt;</span>TFT Meta Team Comps - The Best Comps &amp;amp; Builds in Set 15<span class="html-tag">&lt;/title&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">preconnect</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://cdn.mobalytics.gg/" rel="noreferrer noopener">https://cdn.mobalytics.gg</a>" <span class="html-attribute-name">crossorigin</span>/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">apple-touch-icon</span>" <span class="html-attribute-name">sizes</span>="<span class="html-attribute-value">180x180</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/apple-touch-icon.png" rel="noreferrer noopener">/favicon/apple-touch-icon.png</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">icon</span>" <span class="html-attribute-name">type</span>="<span class="html-attribute-value">image/png</span>" <span class="html-attribute-name">sizes</span>="<span class="html-attribute-value">32x32</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/favicon-32x32.png" rel="noreferrer noopener">/favicon/favicon-32x32.png</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">icon</span>" <span class="html-attribute-name">type</span>="<span class="html-attribute-value">image/png</span>" <span class="html-attribute-name">sizes</span>="<span class="html-attribute-value">16x16</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/favicon-16x16.png" rel="noreferrer noopener">/favicon/favicon-16x16.png</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">manifest</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/site.webmanifest" rel="noreferrer noopener">/favicon/site.webmanifest</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">mask-icon</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/safari-pinned-tab.svg" rel="norefer ...

# %%
pattern_title = r"<head>(.*)</head>"

result_title = re.findall(pattern_title, content)
print(result_title)
# Out:
# ['<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta name="color-scheme" content="light dark">']

# %%
pattern_naglowki = r"<h1>(.*)</h1>"

result_nag = re.findall(pattern_naglowki, content)
print(result_nag)
# Out:
# []

# %%
pattern_link = r'<span class="(.*)"'

result_link = re.findall(pattern_link, content)
print(result_link)
# Out:
# ['html-doctype">&lt;!doctype html&gt;</span><span class="html-tag">&lt;html <span class="html-attribute-name">lang</span>="<span class="html-attribute-value">en</span>"&gt;</span><span class="html-tag">&lt;head&gt;</span><span class="html-tag">&lt;meta <span class="html-attribute-name">charset</span>="<span class="html-attribute-value">utf-8</span>"/&gt;</span><span class="html-tag">&lt;meta <span class="html-attribute-name">name</span>="<span class="html-attribute-value">viewport</span>" <span class="html-attribute-name">content</span>="<span class="html-attribute-value">width=device-width,initial-scale=1,shrink-to-fit=no</span>"/&gt;</span><span class="html-tag">&lt;title <span class="html-attribute-name">data-rh</span>="<span class="html-attribute-value">true</span>"&gt;</span>TFT Meta Team Comps - The Best Comps &amp;amp; Builds in Set 15<span class="html-tag">&lt;/title&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">preconnect</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://cdn.mobalytics.gg/" rel="noreferrer noopener">https://cdn.mobalytics.gg</a>" <span class="html-attribute-name">crossorigin</span>/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">apple-touch-icon</span>" <span class="html-attribute-name">sizes</span>="<span class="html-attribute-value">180x180</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/apple-touch-icon.png" rel="noreferrer noopener">/favicon/apple-touch-icon.png</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">icon</span>" <span class="html-attribute-name">type</span>="<span class="html-attribute-value">image/png</span>" <span class="html-attribute-name">sizes</span>="<span class="html-attribute-value">32x32</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/favicon-32x32.png" rel="noreferrer noopener">/favicon/favicon-32x32.png</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">icon</span>" <span class="html-attribute-name">type</span>="<span class="html-attribute-value">image/png</span>" <span class="html-attribute-name">sizes</span>="<span class="html-attribute-value">16x16</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/favicon-16x16.png" rel="noreferrer noopener">/favicon/favicon-16x16.png</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">manifest</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/site.webmanifest" rel="noreferrer noopener">/favicon/site.webmanifest</a>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">mask-icon</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="https://mobalytics.gg/favicon/safari-pinned-tab.svg" rel="noreferrer noopener">/favicon/safari-pinned-tab.svg</a>" <span class="html-attribute-name">color</span>="<span class="html-attribute-value">#2b2b2d</span>"/&gt;</span><span class="html-tag">&lt;link <span class="html-attribute-name">rel</span>="<span class="html-attribute-value">shortcut icon</span>" <span class="html-attribute-name">href</span>="<a class="html-attribute-value html-resource-link" target="_blank" href="h ...

# %%
pattern_mail = r"\b[A-Za-z0-9_\-.]+@([A-Za-z0-9_\-.]+)\.([A-Za-z0-9]{2,}\b)"

result_mail = re.findall(pattern_link, content)
# print(result_mail[0])
print(len(list(result_mail)))
# Out:
# 1

# %%
with open("cars.csv", encoding="utf-8") as f:
    content = f.read()

print(content[:1000])
# Out:
# "price","currency","brand","body","engine_vol","fuel","drive","power","gearbox_is_manual","prod_year","orig_country","mileage","color","title","offer_timestamp"
# 32900,"PLN","Škoda","Sedan",1598,"Diesel","Przód",115,True,2017,"Polska",175000,"Srebrny","Škoda RAPID","2021-02-28 12:53:00"
# 32500,"PLN","BMW","Kompakt",1598,"Diesel","Tył",116,True,2012,NULL,228000,"Biały","BMW Seria 1 116d","2021-02-28 12:52:00"
# 7900,"PLN","Fiat","Auta małe",1242,"Benzyna","Przód",69,True,2012,"Polska",2610000,"Szary","Fiat Panda 1.2","2021-02-28 12:50:00"
# 39990,"PLN","Kia","SUV",1685,"Diesel","Przód",115,True,2012,"Niemcy",138123,"Szary","Kia Sportage 1.7","2021-02-28 12:57:00"
# 42900,"PLN","Kia","SUV",1685,"Diesel","Przód",115,True,2012,NULL,175962,"Biały","Kia Sportage","2021-02-28 12:50:00"
# 19400,"PLN","BMW","Kombi",2497,"Benzyna+LPG","Tył",177,True,2005,"Niemcy",274000,"Czarny","BMW Seria 5 523i","2021-02-28 12:52:00"
# 106600,"PLN","Renault","SUV",1332,"Benzyna","Przód",140,False,2020,"Polska",7,"Szary","

# %%
pattern_csv = '\d{5,}'
result_csv= re.findall(pattern_csv, content)

len(result_csv)
# Out:
# 181619

# %%
marks = [int(grade) for grade in result_csv]

avg_mark = sum(marks) / len(marks)
avg_mark
# Out:
# 108833.0839449617

# %%
type(marks[0])
# Out:
# int

# %%
marks_above_80 = [mark for mark in marks if mark > 100000]

marks_above_80
# Out:
# [175000,
#  228000,
#  2610000,
#  138123,
#  175962,
#  274000,
#  106600,
#  333570,
#  239700,
#  193121,
#  224000,
#  241000,
#  135000,
#  210000,
#  198500,
#  197000,
#  259000,
#  118000,
#  172000,
#  149000,
#  150606,
#  130000,
#  390000,
#  215000,
#  108000,
#  273000,
#  193000,
#  289000,
#  103000,
#  210000,
#  153000,
#  141978,
#  216880,
#  103000,
#  209680,
#  350000,
#  341000,
#  246690,
#  270937,
#  168000,
#  272000,
#  175000,
#  138000,
#  266000,
#  120000,
#  187068,
#  260000,
#  167000,
#  156956,
#  214658,
#  212000,
#  162000,
#  315635,
#  208926,
#  300000,
#  161000,
#  158000,
#  220000,
#  301000,
#  165000,
#  121000,
#  219000,
#  172000,
#  241000,
#  167566,
#  131000,
#  195000,
#  180830,
#  398000,
#  147435,
#  226200,
#  216000,
#  138000,
#  164000,
#  191000,
#  105431,
#  154000,
#  222000,
#  131346,
#  192000,
#  236000,
#  240000,
#  227948,
#  287600,
#  141000,
#  142046,
#  170000,
#  200000,
#  136000,
#  186000,
#  285461,
#  175300,
#  260000,
#  123200,
#  110000,
#  117947,
#  220123,
#  196000,
#  198234,
#  134000,
#  135000,
#  263000,
#  270000,
#  127861,
#  178000,
#  144000,
#  187000,
#  175060,
#  189000,
#  199000,
#  162822,
#  263700,
#  211109,
#  162000,
#  231000,
#  197234,
#  127500,
#  128000,
#  108000,
#  140000,
#  229000,
#  267500,
#  187000,
#  130000,
#  109000,
#  175000,
#  187000,
#  280000,
#  112799,
#  160550,
#  407000,
#  327528,
#  201500,
#  116000,
#  147400,
#  140000,
#  133000,
#  198000,
#  180000,
#  170000,
#  221000,
#  146000,
#  182236,
#  190000,
#  143600,
#  257000,
#  239138,
#  275728,
#  177000,
#  125000,
#  176286,
#  246507,
#  310000,
#  148197,
#  330000,
#  280000,
#  187468,
#  110000,
#  311000,
#  344000,
#  183895,
#  300000,
#  161000,
#  113000,
#  161000,
#  230000,
#  259000,
#  265000,
#  218000,
#  241000,
#  130000,
#  185000,
#  158800,
#  210200,
#  238000,
#  248500,
#  306900,
#  167000,
#  143041,
#  155403,
#  195800,
#  305000,
#  169500,
#  129386,
#  197000,
#  222000,
#  101300,
#  223000,
#  189000,
#  218000,
#  326427,
#  195000,
#  238000,
#  212000,
#  328000,
#  172000,
#  184000,
#  190000,
#  221000,
#  224000,
#  295201,
#  185000,
#  144990,
#  200000,
#  288869,
#  356000,
#  120000,
#  361200,
#  256630,
#  249131,
#  148000,
#  179000,
#  188000,
#  125550,
#  107990,
#  221000,
#  161000,
#  163000,
#  133000,
#  218000,
#  153000,
#  143900,
#  124200,
#  104500,
#  150000,
#  160000,
#  119000,
#  250000,
#  182000,
#  113898,
#  195772,
#  137000,
#  197100,
#  102000,
#  251000,
#  124400,
#  153900,
#  187900,
#  185000,
#  204000,
#  147041,
#  130000,
#  234500,
#  243000,
#  430000,
#  276000,
#  166911,
#  124000,
#  132000,
#  129000,
#  110000,
#  154000,
#  160000,
#  159000,
#  225000,
#  262000,
#  157466,
#  128012,
#  138500,
#  243187,
#  218000,
#  178000,
#  187000,
#  138824,
#  134000,
#  123000,
#  154000,
#  250000,
#  223260,
#  165000,
#  198000,
#  157000,
#  114000,
#  304000,
#  182000,
#  276000,
#  196910,
#  199000,
#  127500,
#  221585,
#  216000,
#  141000,
#  181000,
#  126000,
#  145000,
#  270000,
#  285579,
#  177000,
#  118000,
#  122000,
#  137000,
#  210000,
#  199000,
#  242000,
#  290000,
#  120000,
#  164000,
#  150000,
#  123000,
#  160000,
#  160000,
#  209871,
#  104000,
#  227500,
#  126670,
#  390000,
#  203200,
#  255000,
#  154000,
#  219000,
#  180000,
#  202942,
#  131200,
#  138500,
#  173500,
#  125289,
#  245000,
#  185000,
#  208000,
#  151009,
#  245800,
#  176000,
#  198000,
#  233890,
#  259000,
#  178600,
#  170698,
#  107800,
#  105000,
#  300000,
#  256000,
#  318413,
#  217000,
#  148900,
#  220627,
#  140000,
#  252397,
#  150000,
#  195500,
#  275000,
#  264787,
#  211750,
#  172000,
#  179000,
#  200000,
#  131559,
#  272354,
#  395957,
#  186000,
#  318600,
#  230000,
#  170000,
#  217000,
#  166167,
#  171600,
#  308000,
#  117800,
#  187000,
#  151163,
#  236287,
#  331000,
#  265000,
#  174000,
#  279500,
#  283196,
#  250675,
#  165000,
#  109000,
#  180000,
#  148000,
#  177000,
#  242000,
#  233000,
#  215000,
#  191000,
#  348100,
#  179432,
#  113418,
#  493000,
#  169303,
#  206500,
#  197000,
#  190000,
#  120078,
#  211000,
#  185000,
#  189058,
#  145000,
#  161000,
#  210523,
#  112900,
#  102000,
#  291000,
#  143000,
#  215000,
#  167000,
#  235000,
#  359715,
#  179000,
#  216000,
#  220237,
#  101718,
#  223781,
#  188000,
#  189000,
#  215000,
#  280000,
#  123500,
#  211606,
#  213973,
#  192500,
#  182000,
#  703470,
#  257633,
#  130000,
#  193786,
#  243000,
#  150000,
#  133000,
#  293250,
#  248000,
#  267000,
#  162364,
#  276000,
#  140000,
#  180000,
#  186000,
#  311000,
#  215000,
#  269000,
#  159160,
#  227000,
#  264767,
#  116000,
#  182000,
#  213505,
#  123000,
#  140607,
#  352000,
#  140400,
#  268600,
#  254200,
#  299500,
#  220000,
#  168000,
#  120799,
#  121611,
#  150000,
#  138200,
#  246996,
#  183500,
#  224000,
#  159985,
#  226000,
#  188000,
#  244000,
#  104500,
#  199230,
#  200000,
#  252487,
#  218000,
#  325000,
#  170800,
#  205000,
#  201000,
#  157000,
#  146000,
#  250000,
#  168000,
#  170000,
#  156000,
#  119900,
#  282260,
#  258000,
#  230000,
#  160000,
#  185794,
#  188000,
#  143000,
#  121000,
#  118000,
#  107670,
#  255335,
#  322222,
#  108000,
#  219000,
#  118000,
#  190000,
#  354000,
#  261500,
#  114000,
#  179000,
#  139800,
#  122000,
#  262800,
#  168000,
#  193700,
#  244215,
#  143758,
#  188300,
#  184000,
#  153000,
#  212000,
#  180000,
#  276000,
#  219523,
#  164000,
#  236000,
#  235000,
#  193000,
#  197000,
#  189000,
#  229000,
#  163000,
#  104755,
#  138000,
#  125000,
#  160000,
#  350140,
#  390000,
#  190367,
#  250000,
#  186820,
#  280000,
#  111000,
#  111450,
#  233784,
#  171995,
#  155000,
#  172850,
#  215000,
#  350000,
#  117000,
#  116850,
#  125000,
#  130000,
#  263000,
#  260000,
#  282547,
#  162000,
#  155538,
#  324000,
#  197000,
#  265000,
#  176000,
#  121000,
#  193400,
#  223500,
#  274000,
#  349721,
#  182000,
#  123124,
#  197000,
#  211000,
#  300000,
#  183000,
#  122000,
#  260000,
#  115513,
#  213600,
#  130000,
#  220000,
#  138900,
#  141172,
#  188800,
#  198000,
#  238000,
#  290000,
#  279852,
#  106500,
#  232000,
#  201322,
#  236000,
#  159815,
#  222000,
#  112000,
#  280000,
#  250100,
#  266298,
#  164000,
#  240000,
#  246000,
#  110000,
#  164756,
#  285000,
#  164000,
#  154701,
#  233600,
#  155000,
#  128900,
#  167900,
#  194000,
#  202000,
#  160000,
#  297000,
#  173000,
#  119600,
#  108000,
#  240000,
#  160500,
#  380000,
#  179000,
#  189000,
#  192102,
#  222000,
#  189000,
#  242500,
#  213000,
#  190765,
#  124000,
#  110000,
#  131500,
#  178000,
#  187000,
#  239000,
#  110814,
#  232000,
#  175000,
#  205966,
#  106987,
#  214110,
#  123400,
#  207000,
#  124000,
#  135000,
#  180924,
#  116000,
#  140000,
#  330000,
#  190000,
#  168700,
#  272000,
#  207000,
#  129900,
#  129900,
#  111247,
#  129000,
#  119000,
#  151643,
#  236080,
#  111250,
#  140386,
#  465000,
#  210500,
#  140000,
#  143000,
#  134000,
#  138199,
#  145000,
#  328278,
#  184595,
#  138000,
#  110000,
#  113448,
#  200100,
#  226476,
#  220000,
#  162935,
#  126500,
#  191386,
#  188000,
#  159000,
#  397000,
#  349000,
#  250000,
#  134000,
#  146000,
#  180000,
#  248000,
#  195000,
#  184000,
#  120000,
#  129727,
#  240000,
#  207000,
#  511351,
#  220000,
#  208000,
#  410000,
#  277000,
#  235945,
#  133000,
#  471000,
#  320000,
#  352000,
#  137000,
#  266000,
#  127190,
#  250000,
#  263000,
#  144600,
#  200990,
#  220000,
#  208000,
#  155000,
#  230000,
#  291461,
#  292000,
#  130000,
#  191000,
#  170000,
#  157322,
#  149000,
#  298000,
#  146000,
#  215000,
#  227500,
#  155709,
#  273220,
#  124900,
#  164900,
#  160000,
#  260500,
#  282000,
#  127800,
#  235000,
#  209300,
#  371000,
#  190000,
#  187300,
#  206100,
#  249078,
#  136000,
#  255800,
#  258500,
#  266969,
#  251000,
#  185000,
#  260000,
#  216000,
#  253000,
#  269000,
#  165450,
#  230000,
#  128000,
#  205000,
#  203000,
#  340000,
#  215000,
#  187300,
#  250000,
#  153000,
#  182000,
#  350000,
#  169000,
#  171000,
#  312000,
#  209500,
#  230000,
#  224700,
#  139000,
#  150000,
#  200941,
#  165000,
#  226000,
#  139147,
#  183116,
#  228969,
#  141000,
#  243000,
#  170000,
#  110000,
#  282000,
#  149000,
#  144100,
#  141200,
#  190000,
#  125800,
#  145000,
#  192625,
#  167000,
#  208000,
#  272000,
#  378000,
#  262962,
#  149102,
#  218353,
#  122000,
#  275900,
#  158861,
#  228000,
#  165000,
#  196144,
#  115000,
#  162500,
#  184190,
#  229088,
#  147258,
#  990000,
#  233320,
#  105129,
#  190000,
#  166000,
#  111000,
#  230000,
#  200000,
#  245200,
#  108900,
#  120000,
#  226000,
#  206235,
#  158000,
#  109900,
#  280000,
#  103000,
#  155000,
#  300000,
#  260000,
#  195575,
#  242000,
#  112000,
#  303600,
#  130000,
#  192000,
#  233830,
#  113000,
#  174893,
#  105000,
#  180675,
#  170000,
#  224100,
#  143000,
#  202160,
#  109950,
#  330000,
#  112000,
#  280000,
#  399800,
#  197186,
#  296000,
#  194000,
#  185000,
#  202500,
#  163000,
#  166000,
#  245288,
#  179519,
#  170000,
#  329000,
#  196000,
#  170874,
#  230000,
#  144000,
#  182500,
#  248500,
#  220000,
#  166073,
#  134000,
#  242000,
#  179819,
#  267604,
#  134000,
#  178000,
#  124000,
#  215000,
#  179767,
#  244000,
#  250212,
#  160000,
#  151000,
#  216500,
#  217500,
#  135300,
#  221000,
#  204000,
#  146900,
#  196000,
#  144000,
#  270000,
#  159000,
#  205000,
#  165242,
#  152000,
#  181000,
#  226000,
#  231587,
#  102500,
#  104550,
#  324633,
#  168000,
#  178285,
#  103000,
#  149500,
#  147000,
#  223008,
#  220000,
#  155600,
#  302000,
#  205000,
#  211000,
#  179000,
#  220000,
#  390000,
#  218961,
#  254721,
#  163000,
#  105000,
#  222051,
#  340000,
#  184000,
#  215000,
#  168000,
#  300000,
#  172630,
#  165000,
#  251000,
#  168000,
#  226000,
#  108000,
#  164000,
#  121799,
#  176000,
#  162773,
#  107000,
#  180000,
#  147092,
#  230000,
#  111925,
#  287000,
#  217000,
#  300000,
#  159595,
#  147000,
#  123000,
#  160100,
#  195000,
#  152000,
#  220000,
#  115000,
#  183910,
#  127000,
#  206000,
#  165000,
#  151300,
#  248000,
#  198000,
#  169000,
#  301000,
#  198479,
#  156000,
#  200000,
#  244000,
#  264090,
#  201000,
#  115000,
#  203300,
#  194212,
#  288000,
#  219000,
#  241457,
#  272445,
#  200000,
#  209511,
#  140700,
#  156159,
#  210000,
#  218000,
#  185625,
#  184000,
#  320000,
#  283917,
#  180000,
#  180000,
#  158000,
#  304500,
#  256000,
#  292762,
#  105000,
#  275000,
#  199000,
#  299512,
#  186519,
#  161500,
#  375381,
#  154000,
#  185000,
#  146500,
#  216000,
#  206000,
#  225000,
#  197000,
#  199850,
#  134000,
#  119000,
#  160000,
#  128000,
#  162000,
#  167000,
#  215500,
#  167000,
#  109000,
#  205000,
#  280000,
#  208000,
#  286209,
#  142000,
#  134000,
#  227586,
#  121000,
#  290000,
#  ...]

# %% [markdown]
# ### CSV

# %% [markdown]
# ### JSON

# %%
import pandas as pd

# %%
json_son = pd.read_csv("weather.csv")
json_son.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
import json

# %%
dir(json)
# Out:
# ['JSONDecodeError',
#  'JSONDecoder',
#  'JSONEncoder',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_default_decoder',
#  '_default_encoder',
#  'codecs',
#  'decoder',
#  'detect_encoding',
#  'dump',
#  'dumps',
#  'encoder',
#  'load',
#  'loads',
#  'scanner']

# %%
json_trening = {"employees": [
                {"id": 14235, "name": "Bob", "date_of_birth": "1982-04-15", "department": "Sales"},
                {"id": 28134, "name": "Susan", "date_of_birth": "1991-09-01", "department": "IT"},
#                 ...
                {"id": 89231, "name": "Andrew", "date_of_birth": "1990-02-15", "department": "Sales"}
              ],
 "departments": ["Sales", "IT", "HR"]}

# %%
type(json_trening)
# Out:
# dict

# %%
json_trening_str = json.dumps(json_trening)

# %%
with open ("json_trening.json", "w", encoding="utf-8") as f:
    f.write(json_trening_str)

# %%
with open ("json_trening.json", "r", encoding="utf-8") as f:
    json_data = json.load(f)

# %%
print(json_data)
# Out:
# {'employees': [{'id': 14235, 'name': 'Bob', 'date_of_birth': '1982-04-15', 'department': 'Sales'}, {'id': 28134, 'name': 'Susan', 'date_of_birth': '1991-09-01', 'department': 'IT'}, {'id': 89231, 'name': 'Andrew', 'date_of_birth': '1990-02-15', 'department': 'Sales'}], 'departments': ['Sales', 'IT', 'HR']}

# %%
with open ("json_trening.json", "w", encoding="utf-8") as f:
    f.write(json_trening_str)

# %%
import requests

# %%
respnse = requests.get("https://www.wp.pl")
print(respnse)
print(type(respnse))
print(dir(respnse))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
url = "http://api.nbp.pl/api/exchangerates/tables/a"

response = requests.get(url)
data = response.json()
data
# Out:
# [{'table': 'A',
#   'no': '159/A/NBP/2025',
#   'effectiveDate': '2025-08-19',
#   'rates': [{'currency': 'bat (Tajlandia)', 'code': 'THB', 'mid': 0.1117},
#    {'currency': 'dolar amerykański', 'code': 'USD', 'mid': 3.6332},
#    {'currency': 'dolar australijski', 'code': 'AUD', 'mid': 2.356},
#    {'currency': 'dolar Hongkongu', 'code': 'HKD', 'mid': 0.4658},
#    {'currency': 'dolar kanadyjski', 'code': 'CAD', 'mid': 2.6293},
#    {'currency': 'dolar nowozelandzki', 'code': 'NZD', 'mid': 2.1504},
#    {'currency': 'dolar singapurski', 'code': 'SGD', 'mid': 2.8309},
#    {'currency': 'euro', 'code': 'EUR', 'mid': 4.242},
#    {'currency': 'forint (Węgry)', 'code': 'HUF', 'mid': 0.010777},
#    {'currency': 'frank szwajcarski', 'code': 'CHF', 'mid': 4.5077},
#    {'currency': 'funt szterling', 'code': 'GBP', 'mid': 4.9123},
#    {'currency': 'hrywna (Ukraina)', 'code': 'UAH', 'mid': 0.0879},
#    {'currency': 'jen (Japonia)', 'code': 'JPY', 'mid': 0.024605},
#    {'currency': 'korona czeska', 'code': 'CZK', 'mid': 0.1734},
#    {'currency': 'korona duńska', 'code': 'DKK', 'mid': 0.5683},
#    {'currency': 'korona islandzka', 'code': 'ISK', 'mid': 0.029582},
#    {'currency': 'korona norweska', 'code': 'NOK', 'mid': 0.3566},
#    {'currency': 'korona szwedzka', 'code': 'SEK', 'mid': 0.381},
#    {'currency': 'lej rumuński', 'code': 'RON', 'mid': 0.8392},
#    {'currency': 'lew (Bułgaria)', 'code': 'BGN', 'mid': 2.1689},
#    {'currency': 'lira turecka', 'code': 'TRY', 'mid': 0.0888},
#    {'currency': 'nowy izraelski szekel', 'code': 'ILS', 'mid': 1.0748},
#    {'currency': 'peso chilijskie', 'code': 'CLP', 'mid': 0.003769},
#    {'currency': 'peso filipińskie', 'code': 'PHP', 'mid': 0.0636},
#    {'currency': 'peso meksykańskie', 'code': 'MXN', 'mid': 0.1933},
#    {'currency': 'rand (Republika Południowej Afryki)',
#     'code': 'ZAR',
#     'mid': 0.2061},
#    {'currency': 'real (Brazylia)', 'code': 'BRL', 'mid': 0.6682},
#    {'currency': 'ringgit (Malezja)', 'code': 'MYR', 'mid': 0.8599},
#    {'currency': 'rupia indonezyjska', 'code': 'IDR', 'mid': 0.00022372},
#    {'currency': 'rupia indyjska', 'code': 'INR', 'mid': 0.041751},
#    {'currency': 'won południowokoreański', 'code': 'KRW', 'mid': 0.002614},
#    {'currency': 'yuan renminbi (Chiny)', 'code': 'CNY', 'mid': 0.506},
#    {'currency': 'SDR (MFW)', 'code': 'XDR', 'mid': 4.9734}]}]

# %%
for rate in data[0]['rates']:
    print(f"Kurs {rate['currency']} ({rate['code']}): {rate['mid']} zl")
# Out:
# Kurs bat (Tajlandia) (THB): 0.1117 zl
# Kurs dolar amerykański (USD): 3.6332 zl
# Kurs dolar australijski (AUD): 2.356 zl
# Kurs dolar Hongkongu (HKD): 0.4658 zl
# Kurs dolar kanadyjski (CAD): 2.6293 zl
# Kurs dolar nowozelandzki (NZD): 2.1504 zl
# Kurs dolar singapurski (SGD): 2.8309 zl
# Kurs euro (EUR): 4.242 zl
# Kurs forint (Węgry) (HUF): 0.010777 zl
# Kurs frank szwajcarski (CHF): 4.5077 zl
# Kurs funt szterling (GBP): 4.9123 zl
# Kurs hrywna (Ukraina) (UAH): 0.0879 zl
# Kurs jen (Japonia) (JPY): 0.024605 zl
# Kurs korona czeska (CZK): 0.1734 zl
# Kurs korona duńska (DKK): 0.5683 zl
# Kurs korona islandzka (ISK): 0.029582 zl
# Kurs korona norweska (NOK): 0.3566 zl
# Kurs korona szwedzka (SEK): 0.381 zl
# Kurs lej rumuński (RON): 0.8392 zl
# Kurs lew (Bułgaria) (BGN): 2.1689 zl
# Kurs lira turecka (TRY): 0.0888 zl
# Kurs nowy izraelski szekel (ILS): 1.0748 zl
# Kurs peso chilijskie (CLP): 0.003769 zl
# Kurs peso filipińskie (PHP): 0.0636 zl
# Kurs peso meksykańskie (MXN): 0.1933 zl
# Kurs rand (Republika Południowej Afryki) (ZAR): 0.2061 zl
# Kurs real (Brazylia) (BRL): 0.6682 zl
# Kurs ringgit (Malezja) (MYR): 0.8599 zl
# Kurs rupia indonezyjska (IDR): 0.00022372 zl
# Kurs rupia indyjska (INR): 0.041751 zl
# Kurs won południowokoreański (KRW): 0.002614 zl
# Kurs yuan renminbi (Chiny) (CNY): 0.506 zl
# Kurs SDR (MFW) (XDR): 4.9734 zl

# %%
pip install scikit-image
# Out:
# Collecting scikit-image
#   Downloading scikit_image-0.21.0-cp38-cp38-win_amd64.whl (22.7 MB)
# Requirement already satisfied: packaging>=21 in c:\users\amanp\pycharmprojects\podstawypython\github\.venv\lib\site-packages (from scikit-image) (25.0)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp38-cp38-win_amd64.whl (4.2 MB)
# Collecting networkx>=2.8
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: numpy>=1.21.1 in c:\users\amanp\pycharmprojects\podstawypython\github\.venv\lib\site-packages (from scikit-image) (1.24.4)
# Collecting scipy>=1.8
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
# Collecting imageio>=2.27
#   Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
# Collecting lazy_loader>=0.2
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\amanp\pycharmprojects\podstawypython\github\.venv\lib\site-packages (from scikit-image) (10.4.0)
# Installing collected packages: tifffile, scipy, PyWavelets, networkx, lazy-loader, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.35.1 lazy-loader-0.4 networkx-3.1 scikit-image-0.21.0 scipy-1.10.1 tifffile-2023.7.10
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.3.1; however, version 25.0.1 is available.
# You should consider upgrading via the 'C:\Users\AmanP\PycharmProjects\PodstawyPython\github\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
from skimage import io

# %%
url = "https://dog.ceo/api/breeds/image/random"

response = requests.get(url)
data = response.json()

image_url = data["message"]
print(image_url)

image = io.imread(image_url)

plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# https://images.dog.ceo/breeds/weimaraner/n02092339_4346.jpg

# %%
url = "https://api.openaq.org/v3/measurements?city=Warszawa&limit=100"

response = requests.get(url)
response.json()
# Out:
# {'message': 'Unauthorized. A valid API key must be provided in the X-API-Key header.'}
