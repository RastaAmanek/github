# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,4].values

# %%
dataset.head()
# Out:
#      RDSpend  Administration  MarketingSpend       State     Profit
# 0  165349.20       136897.80       471784.10    New York  192261.83
# 1  162597.70       151377.59       443898.53  California  191792.06
# 2  153441.51       101145.55       407934.54     Florida  191050.39
# 3  144372.41       118671.85       383199.62    New York  182901.99
# 4  142107.34        91391.77       366168.42     Florida  166187.94

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X = LabelEncoder()
X[:, 3] = labelencoder_X.fit_transform(X[:, 3])

# %%
# X = X[:, 1:]

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 2],
#        [162597.7, 151377.59, 443898.53, 0],
#        [153441.51, 101145.55, 407934.54, 1],
#        [144372.41, 118671.85, 383199.62, 2],
#        [142107.34, 91391.77, 366168.42, 1],
#        [131876.9, 99814.71, 362861.36, 2],
#        [134615.46, 147198.87, 127716.82, 0],
#        [130298.13, 145530.06, 323876.68, 1],
#        [120542.52, 148718.95, 311613.29, 2],
#        [123334.88, 108679.17, 304981.62, 0],
#        [101913.08, 110594.11, 229160.95, 1],
#        [100671.96, 91790.61, 249744.55, 0],
#        [93863.75, 127320.38, 249839.44, 1],
#        [91992.39, 135495.07, 252664.93, 0],
#        [119943.24, 156547.42, 256512.92, 1],
#        [114523.61, 122616.84, 261776.23, 2],
#        [78013.11, 121597.55, 264346.06, 0],
#        [94657.16, 145077.58, 282574.31, 2],
#        [91749.16, 114175.79, 294919.57, 1],
#        [86419.7, 153514.11, 0.0, 2],
#        [76253.86, 113867.3, 298664.47, 0],
#        [78389.47, 153773.43, 299737.29, 2],
#        [73994.56, 122782.75, 303319.26, 1],
#        [67532.53, 105751.03, 304768.73, 1],
#        [77044.01, 99281.34, 140574.81, 2],
#        [64664.71, 139553.16, 137962.62, 0],
#        [75328.87, 144135.98, 134050.07, 1],
#        [72107.6, 127864.55, 353183.81, 2],
#        [66051.52, 182645.56, 118148.2, 1],
#        [65605.48, 153032.06, 107138.38, 2],
#        [61994.48, 115641.28, 91131.24, 1],
#        [61136.38, 152701.92, 88218.23, 2],
#        [63408.86, 129219.61, 46085.25, 0],
#        [55493.95, 103057.49, 214634.81, 1],
#        [46426.07, 157693.92, 210797.67, 0],
#        [46014.02, 85047.44, 205517.64, 2],
#        [28663.76, 127056.21, 201126.82, 1],
#        [44069.95, 51283.14, 197029.42, 0],
#        [20229.59, 65947.93, 185265.1, 2],
#        [38558.51, 82982.09, 174999.3, 0],
#        [28754.33, 118546.05, 172795.67, 0],
#        [27892.92, 84710.77, 164470.71, 1],
#        [23640.93, 96189.63, 148001.11, 0],
#        [15505.73, 127382.3, 35534.17, 2],
#        [22177.74, 154806.14, 28334.72, 0],
#        [1000.23, 124153.04, 1903.93, 2],
#        [1315.46, 115816.21, 297114.46, 1],
#        [0.0, 135426.92, 0.0, 0],
#        [542.05, 51743.15, 0.0, 2],
#        [0.0, 116983.8, 45173.06, 0]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([103959.40508021, 132398.73236694, 133529.03790148,  72958.28368314,
#        179534.78737166, 115533.62584099,  67476.95847883,  98504.36199396,
#        114789.16083781, 168972.21909945])

# %%
# X = dataset.iloc[:, :-1]
# y = dataset.iloc[:, 4]

# %%
X = pd.DataFrame(X)
y = pd.DataFrame(y)

# %%
X.head()
# Out:
#            0          1          2  3
# 0   165349.2   136897.8   471784.1  2
# 1   162597.7  151377.59  443898.53  0
# 2  153441.51  101145.55  407934.54  1
# 3  144372.41  118671.85  383199.62  2
# 4  142107.34   91391.77  366168.42  1

# %%
X.dtypes
# Out:
# R&DSpend          object
# Administration    object
# MarketingSpend    object
# State             object
# dtype: object

# %%
X.columns = ['R&DSpend', 'Administration', 'MarketingSpend', 'State']

# %%
dataset.columns = ['RDSpend', 'Administration', 'MarketingSpend', 'State', 'Profit']

# %%
import statsmodels.formula.api as sm

regressor_OLS = sm.ols(formula = 'Profit ~ RDSpend + MarketingSpend ', data=dataset).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.950
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     450.8
# Date:                Thu, 04 Sep 2025   Prob (F-statistic):           2.16e-31
# Time:                        22:44:43   Log-Likelihood:                -525.54
# No. Observations:                  50   AIC:                             1057.
# Df Residuals:                      47   BIC:                             1063.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       4.698e+04   2689.933     17.464      0.000    4.16e+04    5.24e+04
# RDSpend            0.7966      0.041     19.266      0.000       0.713       0.880
# MarketingSpend     0.0299      0.016      1.927      0.060      -0.001       0.061
# ==============================================================================
# Omnibus:                       14.677   Durbin-Watson:                   1.257
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.161
# Skew:                          -0.939   Prob(JB):                     2.54e-05
# Kurtosis:                       5.575   Cond. No.                     5.32e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
regressor_OLS = sm.ols(formula = 'Profit ~ RDSpend + MarketingSpend + Administration', data=dataset).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Thu, 04 Sep 2025   Prob (F-statistic):           4.53e-30
# Time:                        22:44:44   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       5.012e+04   6572.353      7.626      0.000    3.69e+04    6.34e+04
# RDSpend            0.8057      0.045     17.846      0.000       0.715       0.897
# MarketingSpend     0.0272      0.016      1.655      0.105      -0.006       0.060
# Administration    -0.0268      0.051     -0.526      0.602      -0.130       0.076
# ==============================================================================
# Omnibus:                       14.838   Durbin-Watson:                   1.282
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.442
# Skew:                          -0.949   Prob(JB):                     2.21e-05
# Kurtosis:                       5.586   Cond. No.                     1.40e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.4e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.regression.linear_model import OLS

# %%
X_opt = X.iloc[:, [0,2,3]]

for column in X_opt.columns:
    X_opt[column] = X_opt[column].map(lambda x: float(x))
# Out:
# C:\Users\AmanP\AppData\Local\Temp\ipykernel_70212\3329762694.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_opt[column] = X_opt[column].map(lambda x: float(x))

# %%
regressor_OLS = OLS(endog=y, exog=X_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      0   R-squared (uncentered):                   0.966
# Model:                            OLS   Adj. R-squared (uncentered):              0.963
# Method:                 Least Squares   F-statistic:                              438.9
# Date:                Thu, 04 Sep 2025   Prob (F-statistic):                    2.32e-34
# Time:                        22:56:08   Log-Likelihood:                         -571.05
# No. Observations:                  50   AIC:                                      1148.
# Df Residuals:                      47   BIC:                                      1154.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# R&DSpend           0.9209      0.101      9.109      0.000       0.718       1.124
# MarketingSpend     0.1154      0.036      3.198      0.002       0.043       0.188
# State           1.108e+04   3506.110      3.160      0.003    4025.747    1.81e+04
# ==============================================================================
# Omnibus:                        3.855   Durbin-Watson:                   1.016
# Prob(Omnibus):                  0.146   Jarque-Bera (JB):                2.450
# Skew:                          -0.342   Prob(JB):                        0.294
# Kurtosis:                       2.158   Cond. No.                     2.79e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.79e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_opt.dtypes
# Out:
# R&DSpend          float64
# MarketingSpend    float64
# State             float64
# dtype: object

# %%
data = pd.read_csv('auto-mpg.csv')

# %%
y = data['mpg']
X = data.iloc[:, 1:]

# %%
X.head()
# Out:
#    cylinders  displacement horsepower  weight  acceleration  year  origin  \
# 0          8         307.0        130    3504          12.0    70       1
# 1          8         350.0        165    3693          11.5    70       1
# 2          8         318.0        150    3436          11.0    70       1
# 3          8         304.0        150    3433          12.0    70       1
# 4          8         302.0        140    3449          10.5    70       1
#
#                         name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X.iloc[:, -1] = le.fit_transform(X.iloc[:, -1])

# %%
X.head()
# Out:
#    cylinders  displacement horsepower  weight  acceleration  year  origin name
# 0          8         307.0        130    3504          12.0    70       1   49
# 1          8         350.0        165    3693          11.5    70       1   36
# 2          8         318.0        150    3436          11.0    70       1  231
# 3          8         304.0        150    3433          12.0    70       1   14
# 4          8         302.0        140    3449          10.5    70       1  161
